# %% [markdown]
# To evaluate LLM results, there are 2 main methods: `Ground truth` and `LLM as a judge`.\
# These methods as its pros and cons.
#
# **Ground truth**\
# <u>Pros</u>
# - These methods
#
# <u>Cons</u>
# - Liblidi
#
# **LLM as a judge**\
# <u>Pros</u>
# - Lablada
#
# <u>Cons</u>
# - Lbidlid
