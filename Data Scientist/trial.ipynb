# %% [markdown]
# CV extraction using LLAMA

# %%
import os
from getpass import getpass

if not os.getenv("LLAMA_CLOUD_API_KEY"):
  os.environ['LLAMA_CLOUD_API_KEY'] = getpass("Add your LlamaCloud API Key: ")

# %% [markdown]
# Load job portal dataset

# %%
import pandas as pd

# %%
df = pd.read_csv("dataset\jobs_final.csv", delimiter=";")

df.head()
# Out:
#      site                     job_title          date_posted  \
# 0  indeed                      HR Staff  2026-06-26 00:00:00
# 1  indeed  AI/Machine Learning Engineer  2026-06-26 00:00:00
# 2  indeed                   AI Engineer  2026-06-26 00:00:00
# 3  indeed                  DATA ANALYST  2026-06-26 00:00:00
# 4  indeed          Manager Data Project  2026-06-25 00:00:00
#
#                                           tech_stack  \
# 0                                              Excel
# 1  CI/CD, NLP, Computer Vision, TensorFlow, PyTor...
# 2                                           NLP, LLM
# 3          SQL, Tableau, Power BI, Looker, Python, R
# 4                       SQL, Jira, Azure, Confluence
#
#                                     requirements  min_salary  max_salary  \
# 0               Communication, Bachelor, 3 years         NaN         NaN
# 1  Communication, English, 4 years, Professional         NaN         NaN
# ...

# %% [markdown]
# CV Scoring 1: Job posting skills and tech stack requirements fulfilled by candidate
